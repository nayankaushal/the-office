# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import requests
import seaborn as sns
import re

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.71 Safari/537.36'}

# %%
ep_list = {1:6, 2:22, 3:23, 4:14, 5:26, 6:24, 7:24, 8:24, 9:23}

# %%
a=[]
ep=[]
for i in range(1,10):
    for j in range(1, ep_list[i]+1):
        print('.', end='')
        if j<10:
            url = "https://www.officequotes.net/no{}-0{}.php".format(i,j)
        else:
            url = "https://www.officequotes.net/no{}-{}.php".format(i,j)
        r = requests.get(url, headers=headers)
        html = r.text
        soup = BeautifulSoup(html)
        x = soup.find_all(['a','div', 'span','h1'], class_ = ["quote","entry-title"])
        try:
            ep_title = x[0].text
        except:
            continue
        x.pop(0)
        for t in x:
            ep.append(ep_title)
            a.append(t.text)
value = a
# Out:
# ..........................................................................................................................................................................................

# %%
character =[]
dialogue = []
episode = []
b=" "
for i in range(0,len(value)):
        a_spl = value[i].split(":")
        for j in range(0, len(a_spl)-1):
            try:
                episode.append(ep[i])
                character.append(a_spl[j].split()[-1])
                dialogue.append(a_spl[j+1])
                if a_spl[j+1]!=a_spl[-1]:
                    dialogue[-1] = b.join(dialogue[-1].split()[:-1])
            except:
                continue

# %%
dialogue = [dialogue[idx].strip("  \t\t\t\t\t") for idx in range(0, len(dialogue))]

# %%
episode = pd.Series(episode)
character = pd.Series(character)
dialogue = pd.Series(dialogue)

# %%
df = pd.concat([episode, character, dialogue], axis=1)

# %%
df.columns = ['episode' ,'character', 'dialogue']

# %%
df.to_csv("office_1.csv")

# %%
###################################################

# %%
df = pd.read_csv(r"C:\Users\nakausha\office_1.csv")

# %%
df = df.drop(columns = "Unnamed: 0")

# %%
df['episode']=df['episode'].str.replace(" – ",",").str.replace("  \t\t\t\t",",")

# %%
df['episode'] = df['episode'].str.split(',')

# %%
for i in range(0,len(df['episode'])):
    print('.', end = '')
    df.loc[i,'season'] = df.loc[i,'episode'][0]
    df.loc[i,'episode_no'] = df.loc[i, 'episode'][1]
    try:
        df.loc[i,'title'] = df.loc[i, 'episode'][2]
    except:
        continue
# Out:
# ......................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# ...

# %%
df['title'] = df['title'].str.replace("[^a-zA-Z ]+","").fillna('Pilot')
df = df.drop(columns='episode')
df = df[['season','episode_no','title','character','dialogue']]

# %%
df[df.isnull()]
# Out:
#       season episode_no title character dialogue
# 0        NaN        NaN   NaN       NaN      NaN
# 1        NaN        NaN   NaN       NaN      NaN
# 2        NaN        NaN   NaN       NaN      NaN
# 3        NaN        NaN   NaN       NaN      NaN
# 4        NaN        NaN   NaN       NaN      NaN
# ...      ...        ...   ...       ...      ...
# 59458    NaN        NaN   NaN       NaN      NaN
# 59459    NaN        NaN   NaN       NaN      NaN
# 59460    NaN        NaN   NaN       NaN      NaN
# 59461    NaN        NaN   NaN       NaN      NaN
# 59462    NaN        NaN   NaN       NaN      NaN
#
# [59463 rows x 5 columns]

# %%
df.to_csv("office.csv")
